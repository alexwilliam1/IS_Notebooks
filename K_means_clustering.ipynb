# %% [markdown]
# # Apredizado Não Supervisionado: Clusterização c/ K-means

# %% [markdown]
# ## Importando as bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Aquisição de dados

# %%
dataset = pd.read_csv('iris_flower.csv')
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
X = dataset.iloc[:, [2, 3]].values

# %% [markdown]
# ## 2. Definição o número de clusters

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 10):
    kmeans = KMeans(n_clusters = i, init = 'random', random_state = 42)
    kmeans.fit(X)
    print(kmeans.inertia_)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 10), wcss)
plt.title('Método do cotovelo')
plt.xlabel('Número de clusters')
plt.ylabel('Somatório dos erros quadráticos')
plt.show();
# Out:
# 550.6434666666671
# 86.40394533570999
# 31.38775897435898
# 19.499400899685114
# 14.084349656750577
# 11.079414800946152
# 9.514800341130607
# 8.278238236896588
# 6.832730668024787

# %% [markdown]
# ## 3. Treinamento do modelo -> random 10

# %% [markdown]
# ### 2 CLUSTERS

# %%
kmeans = KMeans(n_clusters = 2, init = 'random', n_init=10)
y_kmeans = kmeans.fit_predict(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[1.49411765 0.26078431]
#  [4.92525253 1.68181818]]

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 70, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 70, c = 'blue', label = 'Cluster 2')
# plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 70, c = 'green', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s = 100, c = 'black', label = 'Centroids')
plt.title('Agrupamento 2 clusters')
plt.xlabel('Tamanho da petala')
plt.ylabel('Largura da petala')
plt.legend()
plt.show();

# %% [markdown]
# ### 3 CLUSTERS

# %%
kmeans = KMeans(n_clusters = 3, init = 'random', n_init=10)
y_kmeans = kmeans.fit_predict(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[5.59583333 2.0375    ]
#  [1.464      0.244     ]
#  [4.26923077 1.34230769]]

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 70, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 70, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 70, c = 'green', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s = 100, c = 'black', label = 'Centroids')
plt.title('Agrupamento 2 clusters')
plt.xlabel('Tamanho da petala')
plt.ylabel('Largura da petala')
plt.legend()
plt.show();

# %% [markdown]
# ## 3. Treinamento do modelo -> random 100

# %% [markdown]
# ### 2 CLUSTERS

# %%
kmeans = KMeans(n_clusters = 2, init = 'random', n_init=100)
y_kmeans = kmeans.fit_predict(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[4.92525253 1.68181818]
#  [1.49411765 0.26078431]]

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 70, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 70, c = 'blue', label = 'Cluster 2')
# plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 70, c = 'green', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s = 100, c = 'black', label = 'Centroids')
plt.title('Agrupamento 2 clusters')
plt.xlabel('Tamanho da petala')
plt.ylabel('Largura da petala')
plt.legend()
plt.show();

# %% [markdown]
# ### 3 CLUSTERS

# %%
kmeans = KMeans(n_clusters = 3, init = 'random', n_init=100)
y_kmeans = kmeans.fit_predict(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[1.464      0.244     ]
#  [4.26923077 1.34230769]
#  [5.59583333 2.0375    ]]

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 70, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 70, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 70, c = 'green', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s = 100, c = 'black', label = 'Centroids')
plt.title('Agrupamento 2 clusters')
plt.xlabel('Tamanho da petala')
plt.ylabel('Largura da petala')
plt.legend()
plt.show();

# %% [markdown]
# ## 3. Treinamento do modelo -> random 1000

# %% [markdown]
# ### 2 CLUSTERS

# %%
kmeans = KMeans(n_clusters = 2, init = 'random', n_init=1000)
y_kmeans = kmeans.fit_predict(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[4.92525253 1.68181818]
#  [1.49411765 0.26078431]]

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 70, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 70, c = 'blue', label = 'Cluster 2')
#plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 70, c = 'green', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s = 100, c = 'black', label = 'Centroids')
plt.title('Agrupamento 2 clusters')
plt.xlabel('Tamanho da petala')
plt.ylabel('Largura da petala')
plt.legend()
plt.show();

# %% [markdown]
# ### 3 CLUSTERS

# %%
kmeans = KMeans(n_clusters = 3, init = 'random', n_init=1000)
y_kmeans = kmeans.fit_predict(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[1.464      0.244     ]
#  [4.26923077 1.34230769]
#  [5.59583333 2.0375    ]]

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 70, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 70, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 70, c = 'green', label = 'Cluster 3')
# plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 70, c = 'yellow', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s = 100, c = 'black', label = 'Centroids')
plt.title('Agrupamento 2 clusters')
plt.xlabel('Tamanho da petala')
plt.ylabel('Largura da petala')
plt.legend()
plt.show();

# %% [markdown]
# ## KMEANS++

# %% [markdown]
# ### 3 CLUSTERS

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++')
y_kmeans = kmeans.fit_predict(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[4.26923077 1.34230769]
#  [1.464      0.244     ]
#  [5.59583333 2.0375    ]]

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 70, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 70, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 70, c = 'green', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s = 100, c = 'black', label = 'Centroids')
plt.title('Agrupamento 2 clusters')
plt.xlabel('Tamanho da petala')
plt.ylabel('Largura da petala')
plt.legend()
plt.show();

# %% [markdown]
# ### 4 CLUSTERS

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++')
y_kmeans = kmeans.fit_predict(X)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[4.76923077 1.60769231]
#  [1.464      0.244     ]
#  [5.80285714 2.11142857]
#  [3.90384615 1.19230769]]

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 70, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 70, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 70, c = 'green', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 70, c = 'yellow', label = 'Cluster 3')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], marker='*', s = 100, c = 'black', label = 'Centroids')
plt.title('Agrupamento 2 clusters')
plt.xlabel('Tamanho da petala')
plt.ylabel('Largura da petala')
plt.legend()
plt.show();
